# %% [markdown]
# The purpose of this notebook is to train an NER model using spaCy to predict entities (drug names, dosage quantities, and delivery mechanisms) within the 'ndc_description' column of the NADAC dataset.
#
# This is necessary to be able to accurately match up drug names in the NADAC and Orange Book dataset (the latter of which does not include dosages and delivery mechanisms within the name).
#
# Previously, a fuzzy matching algorithm was used.  This spaCy model will hopefully lead to a more robust pipeline (no dependence on a possibly-wavering 3rd party package), as well as a reduction in processing time and compute.

# %% [markdown]
# ### Exporting drug names for Doccano annotations

# %%
import pandas as pd
import json

filename = r'C:/Users/Lofgran/Documents/Python Scripts/TDI/DrugPricePredictor/dpp/raw_data/drug_names.json'

# %%
# #Split drug names out to feed to Doccano
# drug_names = pd.DataFrame(prices['ndc_description'].unique()).to_dict()
# drug_names = [v for k, v in drug_names.items()]
# d = [x.strip("'") for x in drug_names[0].values()]

# #Write file to disk
# with open(filename, 'w', encoding='utf-8') as outfile:
#     json.dump(d, outfile, ensure_ascii=False, indent=4)

# %%
#Read file back in (as a check)
with open(filename) as infile: 
    d = json.load(infile)
# d

# %% [markdown]
# ### Import annotations

# %%
filepath = 'annotations.json1'
with open(filepath, 'r') as infile:
    d = [json.loads(line) for line in infile]
print('Original format: ', d[1], '\n')
print('Total length: ', len(d))
# Out:
# Original format:  {'id': 17722, 'text': '"12-HR DECONGEST 120 MG CAPLET",', 'meta': {}, 'annotation_approver': None, 'labels': [[1, 16, 'drug_name'], [17, 23, 'quantity'], [24, 30, 'mechanism']]}
#
# Total length:  8859

# %% [markdown]
# ### Format annotation data for trainings

# %%
#Subtract 1 from all annotation location values
for i in d:
    for x in i['labels']:
#         print('Unmodified: ', x)
        x[0] = x[0] - 1
        x[1] = x[1] - 1
        
        if 'drug_name' in x[2]:
            x[2] = 'DRUGNAME'
        x[2] = x[2].upper()
    
TRAIN_DATA = []
# TEST_DATA = []
for i in d:
    i['text'] = i['text'].replace('"', '').strip("'").strip(',')
    i['labels'] = [tuple(x) for x in i['labels']] 
    if len(i['labels'])!=0:     
        TRAIN_DATA.append((i['text'], {'entities': i['labels']}))
#     else:
#         TEST_DATA.append((i['text'], {'entities': i['labels']}))


#Print results
print('Number of annotations: ', len(TRAIN_DATA))
print('\n')
print('Example entry: ', d[1])
print('\n')
print('Example annotation: ', d[1]['labels'])
print('\n')
print('New annotation format: ', TRAIN_DATA[1])
# Out:
# Number of annotations:  1000
#
#
# Example entry:  {'id': 17722, 'text': '12-HR DECONGEST 120 MG CAPLET', 'meta': {}, 'annotation_approver': None, 'labels': [(0, 15, 'DRUGNAME'), (16, 22, 'QUANTITY'), (23, 29, 'MECHANISM')]}
#
#
# Example annotation:  [(0, 15, 'DRUGNAME'), (16, 22, 'QUANTITY'), (23, 29, 'MECHANISM')]
#
#
# New annotation format:  ('12HR NASAL DECONGEST ER 120 MG', {'entities': [(0, 23, 'DRUGNAME'), (24, 30, 'QUANTITY')]})

# %%
### Split data into train and test sets

# %%
TEST_DATA = TRAIN_DATA[:200]
TRAIN_DATA = TRAIN_DATA[200:]
print(len(TRAIN_DATA), len(TEST_DATA))
# Out:
# 800 200

# %% [markdown]
# ### Train model to recognize named entities

# %%
from __future__ import unicode_literals, print_function

import plac
import random
import warnings
from pathlib import Path
import spacy
from spacy.util import minibatch, compounding

model = None
new_model_name="drugnames"
output_dir=None
n_iter=30

# Set up the pipeline and entity recognizer, and train the new entity
random.seed(0)
if model is not None:
    nlp = spacy.load(model)  # load existing spaCy model
    print("Loaded model '%s'" % model)
else:
    nlp = spacy.blank("en")  # create blank Language class
    print("Created blank 'en' model")
# Add entity recognizer to model if it's not in the pipeline
# nlp.create_pipe works for built-ins that are registered with spaCy
if "ner" not in nlp.pipe_names:
    ner = nlp.create_pipe("ner")
    nlp.add_pipe(ner)
# otherwise, get it, so we can add labels to it
else:
    ner = nlp.get_pipe("ner")

#     ner.add_label(LABEL)  # add new entity label to entity recognizer
#     # Adding extraneous labels shouldn't mess anything up
ner.add_label("DRUGNAME")
ner.add_label("QUANTITY")
ner.add_label("MECHANISM")
if model is None:
    optimizer = nlp.begin_training()
else:
    optimizer = nlp.resume_training()
move_names = list(ner.move_names)
# get names of other pipes to disable them during training
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]
# only train NER
with nlp.disable_pipes(*other_pipes), warnings.catch_warnings():
    # show warnings for misaligned entity spans once
    warnings.filterwarnings("once", category=UserWarning, module='spacy')

    sizes = compounding(1.0, 4.0, 1.001)
    # batch up the examples using spaCy's minibatch
    for itn in range(n_iter):
        random.shuffle(TRAIN_DATA)
        batches = minibatch(TRAIN_DATA, size=sizes)
        losses = {}
        for batch in batches:
#                 print('batch: ', batch)
            texts, annotations = zip(*batch)
#                 print('texts: ', texts)
#                 print('annotations: ', annotations)
            nlp.update(texts, annotations, sgd=optimizer, drop=0.35, losses=losses)
        print("Losses", losses)
            
# nlp = main(model=None, new_model_name="drugnames", output_dir=None, n_iter=30)
# Out:
# Created blank 'en' model
# C:\Users\Lofgran\anaconda3\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "KURVELO-28 TABLET" with entities "[(8, 10, 'QUANTITY'), (11, 17, 'MECHANISM'), (0, 7...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Lofgran\anaconda3\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "ELINEST-28 TABLET" with entities "[(0, 7, 'DRUGNAME'), (8, 10, 'QUANTITY'), (11, 17,...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Lofgran\anaconda3\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "RIMSO-50 SOLUTION" with entities "[(0, 5, 'DRUGNAME'), (6, 8, 'QUANTITY'), (9, 17, '...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# Losses {'ner': 1030.3045017955726}
# Losses {'ner': 328.56071633399915}
# Losses {'ner': 195.40281845569953}
# Losses {'ner': 167.335686903269}
# Losses {'ner': 148.01783796988852}
# Losses {'ner': 105.5387535672811}
# Losses {'ner': 75.95050248097279}
# Losses {'ner': 64.15366610125628}
# Losses {'ner': 70.4490965246204}
# Losses {'ner': 69.26446745257009}
# Losses {'ner': 58.188177957116956}
# Losses {'ner': 58.625135219015284}
# Losses {'ner': 41.25419918810883}
# Losses {'ner': 48.57459543858635}
# Losses {'ner': 86.77407473569932}
# Losses {'ner': 85.2736846660122}
# Losses {'ner': 45.32622018363614}
# Losses {'ner': 75.34914966032673}
# Losses {'ner': 44.29854706866299}
# Losses {'ner': 31.96496087015578}
# Losses {'ner': 37.27700909205229}
# Losses {'ner': 52.837022537564785}
# Losses {'ner': 41.0440150733066}
# Losses {'ner': 56.85392993243509}
# Losses {'ner': 43.35341415260379}
# Losses {'ner': 58.753545732089414}
# Losses {'ner': 38.73231411299899}
# Losses {'ner': 20.549124993498513}
# Losses {'ner': 49.144281610955616}
# Losses {'ner': 44.57899614260091}

# %% [markdown]
# ### Evaluate model

# %%
import spacy
from spacy.gold import GoldParse
from spacy.scorer import Scorer
import pprint

def evaluate(ner_model, examples):
    scorer = Scorer()
    for input_, annot in examples:
        doc_gold_text = ner_model.make_doc(input_)
        gold = GoldParse(doc_gold_text, entities=annot['entities'])
        pred_value = ner_model(input_)
        scorer.score( pred_value, gold)
    return scorer.scores

results = evaluate(nlp, TEST_DATA)

pprint.pprint(results)
# Out:
# {'ents_f': 97.79735682819384,
#  'ents_p': 97.7112676056338,
#  'ents_per_type': {'DRUGNAME': {'f': 96.74185463659147,
#                                 'p': 96.98492462311557,
#                                 'r': 96.5},
#                    'MECHANISM': {'f': 98.91304347826086,
#                                  'p': 98.91304347826086,
#                                  'r': 98.91304347826086},
#                    'QUANTITY': {'f': 97.82608695652173,
#                                 'p': 97.2972972972973,
#                                 'r': 98.36065573770492}},
#  'ents_r': 97.88359788359789,
#  'las': 0.0,
#  'las_per_type': {'': {'f': 0.0, 'p': 0.0, 'r': 0.0}},
#  'tags_acc': 0.0,
#  'textcat_score': 0.0,
#  'textcats_per_cat': {},
#  'token_acc': 100.0,
#  'uas': 0.0}

# %%
#TESTING
for text, _ in TEST_DATA:
    doc = nlp(text)
    print(text)
    print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
#     print("Tokens", [(t.text, t.ent_type_, t.ent_iob) for t in doc])
    print('\n')
# Out:
# 12-HR DECONGEST 120 MG CAPLET
# Entities [('12-HR DECONGEST', 'DRUGNAME'), ('120 MG', 'QUANTITY'), ('CAPLET', 'MECHANISM')]
# Tokens [('12-HR', 'DRUGNAME', 3), ('DECONGEST', 'DRUGNAME', 1), ('120', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPLET', 'MECHANISM', 3)]
#
#
# 12HR NASAL DECONGEST ER 120 MG
# Entities [('12HR NASAL DECONGEST ER', 'DRUGNAME'), ('120 MG', 'QUANTITY')]
# Tokens [('12HR', 'DRUGNAME', 3), ('NASAL', 'DRUGNAME', 1), ('DECONGEST', 'DRUGNAME', 1), ('ER', 'DRUGNAME', 1), ('120', 'QUANTITY', 3), ('MG', 'QUANTITY', 1)]
#
#
# 24H NASAL ALLERGY 55 MCG SPRAY
# Entities [('24H NASAL ALLERGY', 'DRUGNAME'), ('55 MCG', 'QUANTITY'), ('SPRAY', 'MECHANISM')]
# Tokens [('24H', 'DRUGNAME', 3), ('NASAL', 'DRUGNAME', 1), ('ALLERGY', 'DRUGNAME', 1), ('55', 'QUANTITY', 3), ('MCG', 'QUANTITY', 1), ('SPRAY', 'MECHANISM', 3)]
#
#
# 24HR ALLERGY(LEVOCETIRZN) 5 MG
# Entities [('24HR ALLERGY(LEVOCETIRZN', 'DRUGNAME'), (') 5 MG', 'QUANTITY')]
# Tokens [('24HR', 'DRUGNAME', 3), ('ALLERGY(LEVOCETIRZN', 'DRUGNAME', 1), (')', 'QUANTITY', 3), ('5', 'QUANTITY', 1), ('MG', 'QUANTITY', 1)]
#
#
# 8 HOUR ACETAMINOPHEN ER 650 MG
# Entities [('8 HOUR ACETAMINOPHEN ER', 'DRUGNAME'), ('650 MG', 'QUANTITY')]
# Tokens [('8', 'DRUGNAME', 3), ('HOUR', 'DRUGNAME', 1), ('ACETAMINOPHEN', 'DRUGNAME', 1), ('ER', 'DRUGNAME', 1), ('650', 'QUANTITY', 3), ('MG', 'QUANTITY', 1)]
#
#
# 8HR ARTHRITIS PAIN ER 650 MG
# Entities [('8HR ARTHRITIS PAIN ER', 'DRUGNAME'), ('650 MG', 'QUANTITY')]
# Tokens [('8HR', 'DRUGNAME', 3), ('ARTHRITIS', 'DRUGNAME', 1), ('PAIN', 'DRUGNAME', 1), ('ER', 'DRUGNAME', 1), ('650', 'QUANTITY', 3), ('MG', 'QUANTITY', 1)]
#
#
# 8HR MUSCLE ACHE-PAIN ER 650 MG
# Entities [('8HR MUSCLE', 'QUANTITY'), ('650 MG', 'QUANTITY')]
# Tokens [('8HR', 'QUANTITY', 3), ('MUSCLE', 'QUANTITY', 1), ('ACHE', '', 2), ('-', '', 2), ('PAIN', '', 2), ('ER', '', 2), ('650', 'QUANTITY', 3), ('MG', 'QUANTITY', 1)]
#
#
# ABACAVIR 300 MG TABLET
# Entities [('ABACAVIR', 'DRUGNAME'), ('300 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ABACAVIR', 'DRUGNAME', 3), ('300', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ABILIFY 10 MG TABLET
# Entities [('ABILIFY', 'DRUGNAME'), ('10 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ABILIFY', 'DRUGNAME', 3), ('10', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ABILIFY 15 MG TABLET
# Entities [('ABILIFY', 'DRUGNAME'), ('15 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ABILIFY', 'DRUGNAME', 3), ('15', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ABILIFY 2 MG TABLET
# Entities [('ABILIFY', 'DRUGNAME'), ('2 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ABILIFY', 'DRUGNAME', 3), ('2', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ABILIFY 5 MG TABLET
# Entities [('ABILIFY', 'DRUGNAME'), ('5 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ABILIFY', 'DRUGNAME', 3), ('5', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ABILIFY MAINTENA ER 300 MG VL
# Entities [('ABILIFY MAINTENA ER', 'DRUGNAME'), ('300 MG', 'QUANTITY'), ('VL', 'MECHANISM')]
# Tokens [('ABILIFY', 'DRUGNAME', 3), ('MAINTENA', 'DRUGNAME', 1), ('ER', 'DRUGNAME', 1), ('300', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('VL', 'MECHANISM', 3)]
#
#
# ABILIFY MAINTENA ER 400 MG SYR
# Entities [('ABILIFY MAINTENA ER', 'DRUGNAME'), ('400 MG', 'QUANTITY'), ('SYR', 'MECHANISM')]
# Tokens [('ABILIFY', 'DRUGNAME', 3), ('MAINTENA', 'DRUGNAME', 1), ('ER', 'DRUGNAME', 1), ('400', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('SYR', 'MECHANISM', 3)]
#
#
# ABILIFY MAINTENA ER 400 MG VL
# Entities [('ABILIFY MAINTENA ER', 'DRUGNAME'), ('400 MG', 'QUANTITY'), ('VL', 'MECHANISM')]
# Tokens [('ABILIFY', 'DRUGNAME', 3), ('MAINTENA', 'DRUGNAME', 1), ('ER', 'DRUGNAME', 1), ('400', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('VL', 'MECHANISM', 3)]
#
#
# ABIRATERONE ACETATE 250 MG TAB
# Entities [('ABIRATERONE ACETATE', 'DRUGNAME'), ('250 MG', 'QUANTITY'), ('TAB', 'MECHANISM')]
# Tokens [('ABIRATERONE', 'DRUGNAME', 3), ('ACETATE', 'DRUGNAME', 1), ('250', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TAB', 'MECHANISM', 3)]
#
#
# ABSORICA 40 MG CAPSULE
# Entities [('ABSORICA', 'DRUGNAME'), ('40 MG', 'QUANTITY'), ('CAPSULE', 'MECHANISM')]
# Tokens [('ABSORICA', 'DRUGNAME', 3), ('40', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPSULE', 'MECHANISM', 3)]
#
#
# ACAMPROSATE CALC DR 333 MG TAB
# Entities [('ACAMPROSATE CALC DR', 'DRUGNAME'), ('333 MG', 'QUANTITY'), ('TAB', 'MECHANISM')]
# Tokens [('ACAMPROSATE', 'DRUGNAME', 3), ('CALC', 'DRUGNAME', 1), ('DR', 'DRUGNAME', 1), ('333', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TAB', 'MECHANISM', 3)]
#
#
# ACARBOSE 100 MG TABLET
# Entities [('ACARBOSE', 'DRUGNAME'), ('100 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ACARBOSE', 'DRUGNAME', 3), ('100', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ACARBOSE 25 MG TABLET
# Entities [('ACARBOSE', 'DRUGNAME'), ('25 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ACARBOSE', 'DRUGNAME', 3), ('25', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ACEBUTOLOL 200 MG CAPSULE
# Entities [('ACEBUTOLOL', 'DRUGNAME'), ('200 MG', 'QUANTITY'), ('CAPSULE', 'MECHANISM')]
# Tokens [('ACEBUTOLOL', 'DRUGNAME', 3), ('200', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPSULE', 'MECHANISM', 3)]
#
#
# ACEBUTOLOL 400 MG CAPSULE
# Entities [('ACEBUTOLOL', 'DRUGNAME'), ('400 MG', 'QUANTITY'), ('CAPSULE', 'MECHANISM')]
# Tokens [('ACEBUTOLOL', 'DRUGNAME', 3), ('400', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPSULE', 'MECHANISM', 3)]
#
#
# ACEPHEN 120 MG SUPPOSITORY
# Entities [('ACEPHEN', 'DRUGNAME'), ('120 MG', 'QUANTITY'), ('SUPPOSITORY', 'MECHANISM')]
# Tokens [('ACEPHEN', 'DRUGNAME', 3), ('120', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('SUPPOSITORY', 'MECHANISM', 3)]
#
#
# ACEPHEN 650 MG SUPPOSITORY
# Entities [('ACEPHEN', 'DRUGNAME'), ('650 MG', 'QUANTITY'), ('SUPPOSITORY', 'MECHANISM')]
# Tokens [('ACEPHEN', 'DRUGNAME', 3), ('650', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('SUPPOSITORY', 'MECHANISM', 3)]
#
#
# ACETAMINOPHEN 160 MG/5 ML LIQ
# Entities [('ACETAMINOPHEN', 'DRUGNAME'), ('160 MG/5 ML', 'QUANTITY'), ('LIQ', 'MECHANISM')]
# Tokens [('ACETAMINOPHEN', 'DRUGNAME', 3), ('160', 'QUANTITY', 3), ('MG/5', 'QUANTITY', 1), ('ML', 'QUANTITY', 1), ('LIQ', 'MECHANISM', 3)]
#
#
# ACETAMINOPHEN 325 MG GELCAP
# Entities [('ACETAMINOPHEN', 'DRUGNAME'), ('325 MG', 'QUANTITY'), ('GELCAP', 'MECHANISM')]
# Tokens [('ACETAMINOPHEN', 'DRUGNAME', 3), ('325', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('GELCAP', 'MECHANISM', 3)]
#
#
# ACETAMINOPHEN 325 MG TABLET
# Entities [('ACETAMINOPHEN', 'DRUGNAME'), ('325 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ACETAMINOPHEN', 'DRUGNAME', 3), ('325', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ACETAMINOPHEN 500 MG CAPLET
# Entities [('ACETAMINOPHEN', 'DRUGNAME'), ('500 MG', 'QUANTITY'), ('CAPLET', 'MECHANISM')]
# Tokens [('ACETAMINOPHEN', 'DRUGNAME', 3), ('500', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPLET', 'MECHANISM', 3)]
#
#
# ACETAMINOPHEN 500 MG SOFTGEL
# Entities [('ACETAMINOPHEN', 'DRUGNAME'), ('500 MG', 'QUANTITY'), ('SOFTGEL', 'MECHANISM')]
# Tokens [('ACETAMINOPHEN', 'DRUGNAME', 3), ('500', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('SOFTGEL', 'MECHANISM', 3)]
#
#
# ACETAMINOPHEN 500 MG TABLET
# Entities [('ACETAMINOPHEN', 'DRUGNAME'), ('500 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ACETAMINOPHEN', 'DRUGNAME', 3), ('500', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ACETAMINOPHEN 650 MG SUPPOS
# Entities [('ACETAMINOPHEN', 'DRUGNAME'), ('650 MG', 'QUANTITY'), ('SUPPOS', 'MECHANISM')]
# Tokens [('ACETAMINOPHEN', 'DRUGNAME', 3), ('650', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('SUPPOS', 'MECHANISM', 3)]
#
#
# ACETAMINOPHEN-COD #2 TABLET
# Entities [('ACETAMINOPHEN-COD', 'DRUGNAME'), ('#', 'MECHANISM'), ('2', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ACETAMINOPHEN', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('COD', 'DRUGNAME', 1), ('#', 'MECHANISM', 3), ('2', 'QUANTITY', 3), ('TABLET', 'MECHANISM', 3)]
#
#
# ACETAMINOPHEN-COD #4 TABLET
# Entities [('ACETAMINOPHEN-COD', 'DRUGNAME'), ('#4', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ACETAMINOPHEN', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('COD', 'DRUGNAME', 1), ('#', 'QUANTITY', 3), ('4', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ACETAMINOPHEN-CODEINE 120 MG-12 MG/5 ML SOLUTION
# Entities [('ACETAMINOPHEN-CODEINE', 'DRUGNAME'), ('120 MG-12 MG/5 ML', 'QUANTITY'), ('SOLUTION', 'MECHANISM')]
# Tokens [('ACETAMINOPHEN', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('CODEINE', 'DRUGNAME', 1), ('120', 'QUANTITY', 3), ('MG-12', 'QUANTITY', 1), ('MG/5', 'QUANTITY', 1), ('ML', 'QUANTITY', 1), ('SOLUTION', 'MECHANISM', 3)]
#
#
# ACETAMINOPHEN CONGST-PAIN CPLT
# Entities [('ACETAMINOPHEN CONGST-PAIN CPLT', 'DRUGNAME')]
# Tokens [('ACETAMINOPHEN', 'DRUGNAME', 3), ('CONGST', 'DRUGNAME', 1), ('-', 'DRUGNAME', 1), ('PAIN', 'DRUGNAME', 1), ('CPLT', 'DRUGNAME', 1)]
#
#
# ACETAMINOPHEN ER 650 MG CAPLET
# Entities [('ACETAMINOPHEN ER', 'DRUGNAME'), ('650 MG', 'QUANTITY'), ('CAPLET', 'MECHANISM')]
# Tokens [('ACETAMINOPHEN', 'DRUGNAME', 3), ('ER', 'DRUGNAME', 1), ('650', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPLET', 'MECHANISM', 3)]
#
#
# ACETAMINOPHEN PM CAPLET
# Entities [('ACETAMINOPHEN PM', 'DRUGNAME'), ('CAPLET', 'MECHANISM')]
# Tokens [('ACETAMINOPHEN', 'DRUGNAME', 3), ('PM', 'DRUGNAME', 1), ('CAPLET', 'MECHANISM', 3)]
#
#
# ACETAZOLAMIDE 125 MG TABLET
# Entities [('ACETAZOLAMIDE', 'DRUGNAME'), ('125 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ACETAZOLAMIDE', 'DRUGNAME', 3), ('125', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ACETAZOLAMIDE 250 MG TABLET
# Entities [('ACETAZOLAMIDE', 'DRUGNAME'), ('250 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ACETAZOLAMIDE', 'DRUGNAME', 3), ('250', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ACETAZOLAMIDE ER 500 MG CAP
# Entities [('ACETAZOLAMIDE ER', 'DRUGNAME'), ('500 MG', 'QUANTITY'), ('CAP', 'MECHANISM')]
# Tokens [('ACETAZOLAMIDE', 'DRUGNAME', 3), ('ER', 'DRUGNAME', 1), ('500', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAP', 'MECHANISM', 3)]
#
#
# ACETYLCYSTEINE 10% VIAL
# Entities [('ACETYLCYSTEINE', 'DRUGNAME'), ('10%', 'QUANTITY'), ('VIAL', 'MECHANISM')]
# Tokens [('ACETYLCYSTEINE', 'DRUGNAME', 3), ('10', 'QUANTITY', 3), ('%', 'QUANTITY', 1), ('VIAL', 'MECHANISM', 3)]
#
#
# ACETYLCYSTEINE 20% VIAL
# Entities [('ACETYLCYSTEINE', 'DRUGNAME'), ('20%', 'QUANTITY'), ('VIAL', 'MECHANISM')]
# Tokens [('ACETYLCYSTEINE', 'DRUGNAME', 3), ('20', 'QUANTITY', 3), ('%', 'QUANTITY', 1), ('VIAL', 'MECHANISM', 3)]
#
#
# ACID CONTROL 150 MG TABLET
# Entities [('ACID', 'DRUGNAME'), ('CONTROL', 'MECHANISM'), ('150 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ACID', 'DRUGNAME', 3), ('CONTROL', 'MECHANISM', 3), ('150', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ACID CONTROLLER 10 MG TABLET
# Entities [('ACID CONTROLLER', 'DRUGNAME'), ('10 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ACID', 'DRUGNAME', 3), ('CONTROLLER', 'DRUGNAME', 1), ('10', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ACID GONE ANTACID LIQUID
# Entities [('ACID GONE ANTACID', 'DRUGNAME'), ('LIQUID', 'MECHANISM')]
# Tokens [('ACID', 'DRUGNAME', 3), ('GONE', 'DRUGNAME', 1), ('ANTACID', 'DRUGNAME', 1), ('LIQUID', 'MECHANISM', 3)]
#
#
# ACID GONE TABLET CHEW
# Entities [('ACID GONE', 'DRUGNAME'), ('TABLET CHEW', 'MECHANISM')]
# Tokens [('ACID', 'DRUGNAME', 3), ('GONE', 'DRUGNAME', 1), ('TABLET', 'MECHANISM', 3), ('CHEW', 'MECHANISM', 1)]
#
#
# ACID REDUCER 10 MG TABLET
# Entities [('ACID REDUCER', 'DRUGNAME'), ('10 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ACID', 'DRUGNAME', 3), ('REDUCER', 'DRUGNAME', 1), ('10', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ACID REDUCER 20 MG TABLET
# Entities [('ACID REDUCER', 'DRUGNAME'), ('20 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ACID', 'DRUGNAME', 3), ('REDUCER', 'DRUGNAME', 1), ('20', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ACID REDUCER DR 20 MG CAP
# Entities [('ACID REDUCER DR', 'DRUGNAME'), ('20 MG', 'QUANTITY'), ('CAP', 'MECHANISM')]
# Tokens [('ACID', 'DRUGNAME', 3), ('REDUCER', 'DRUGNAME', 1), ('DR', 'DRUGNAME', 1), ('20', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAP', 'MECHANISM', 3)]
#
#
# ACIPHEX DR 20 MG TABLET
# Entities [('ACIPHEX DR', 'DRUGNAME'), ('20 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ACIPHEX', 'DRUGNAME', 3), ('DR', 'DRUGNAME', 1), ('20', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ACITRETIN 10 MG CAPSULE
# Entities [('ACITRETIN', 'DRUGNAME'), ('10 MG', 'QUANTITY'), ('CAPSULE', 'MECHANISM')]
# Tokens [('ACITRETIN', 'DRUGNAME', 3), ('10', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPSULE', 'MECHANISM', 3)]
#
#
# ACITRETIN 25 MG CAPSULE
# Entities [('ACITRETIN', 'DRUGNAME'), ('25 MG', 'QUANTITY'), ('CAPSULE', 'MECHANISM')]
# Tokens [('ACITRETIN', 'DRUGNAME', 3), ('25', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPSULE', 'MECHANISM', 3)]
#
#
# ACNE MEDICATION 10% LOTION
# Entities [('ACNE MEDICATION', 'DRUGNAME'), ('10%', 'QUANTITY'), ('LOTION', 'MECHANISM')]
# Tokens [('ACNE', 'DRUGNAME', 3), ('MEDICATION', 'DRUGNAME', 1), ('10', 'QUANTITY', 3), ('%', 'QUANTITY', 1), ('LOTION', 'MECHANISM', 3)]
#
#
# ACNE MEDICATION 2.5% GEL
# Entities [('ACNE MEDICATION', 'DRUGNAME'), ('2.5%', 'QUANTITY'), ('GEL', 'MECHANISM')]
# Tokens [('ACNE', 'DRUGNAME', 3), ('MEDICATION', 'DRUGNAME', 1), ('2.5', 'QUANTITY', 3), ('%', 'QUANTITY', 1), ('GEL', 'MECHANISM', 3)]
#
#
# ACNE MEDICATION 5% GEL
# Entities [('ACNE MEDICATION', 'DRUGNAME'), ('5%', 'QUANTITY'), ('GEL', 'MECHANISM')]
# Tokens [('ACNE', 'DRUGNAME', 3), ('MEDICATION', 'DRUGNAME', 1), ('5', 'QUANTITY', 3), ('%', 'QUANTITY', 1), ('GEL', 'MECHANISM', 3)]
#
#
# ACNE MEDICATION 5% LOTION
# Entities [('ACNE MEDICATION', 'DRUGNAME'), ('5%', 'QUANTITY'), ('LOTION', 'MECHANISM')]
# Tokens [('ACNE', 'DRUGNAME', 3), ('MEDICATION', 'DRUGNAME', 1), ('5', 'QUANTITY', 3), ('%', 'QUANTITY', 1), ('LOTION', 'MECHANISM', 3)]
#
#
# ACYCLOVIR 200 MG/5 ML SUSP
# Entities [('ACYCLOVIR', 'DRUGNAME'), ('200 MG/5 ML', 'QUANTITY'), ('SUSP', 'MECHANISM')]
# Tokens [('ACYCLOVIR', 'DRUGNAME', 3), ('200', 'QUANTITY', 3), ('MG/5', 'QUANTITY', 1), ('ML', 'QUANTITY', 1), ('SUSP', 'MECHANISM', 3)]
#
#
# ACYCLOVIR 200 MG CAPSULE
# Entities [('ACYCLOVIR', 'DRUGNAME'), ('200 MG', 'QUANTITY'), ('CAPSULE', 'MECHANISM')]
# Tokens [('ACYCLOVIR', 'DRUGNAME', 3), ('200', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPSULE', 'MECHANISM', 3)]
#
#
# ACYCLOVIR 400 MG TABLET
# Entities [('ACYCLOVIR', 'DRUGNAME'), ('400 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ACYCLOVIR', 'DRUGNAME', 3), ('400', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ACYCLOVIR 5% CREAM
# Entities [('ACYCLOVIR', 'DRUGNAME'), ('5%', 'QUANTITY'), ('CREAM', 'MECHANISM')]
# Tokens [('ACYCLOVIR', 'DRUGNAME', 3), ('5', 'QUANTITY', 3), ('%', 'QUANTITY', 1), ('CREAM', 'MECHANISM', 3)]
#
#
# ACYCLOVIR 800 MG TABLET
# Entities [('ACYCLOVIR', 'DRUGNAME'), ('800 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ACYCLOVIR', 'DRUGNAME', 3), ('800', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ACZONE 5% GEL
# Entities [('ACZONE', 'DRUGNAME'), ('5%', 'QUANTITY'), ('GEL', 'MECHANISM')]
# Tokens [('ACZONE', 'DRUGNAME', 3), ('5', 'QUANTITY', 3), ('%', 'QUANTITY', 1), ('GEL', 'MECHANISM', 3)]
#
#
# ACZONE 7.5% GEL PUMP
# Entities [('ACZONE', 'DRUGNAME'), ('7.5%', 'QUANTITY'), ('GEL PUMP', 'MECHANISM')]
# Tokens [('ACZONE', 'DRUGNAME', 3), ('7.5', 'QUANTITY', 3), ('%', 'QUANTITY', 1), ('GEL', 'MECHANISM', 3), ('PUMP', 'MECHANISM', 1)]
#
#
# ADAPALENE 0.1% CREAM
# Entities [('ADAPALENE', 'DRUGNAME'), ('0.1%', 'QUANTITY'), ('CREAM', 'MECHANISM')]
# Tokens [('ADAPALENE', 'DRUGNAME', 3), ('0.1', 'QUANTITY', 3), ('%', 'QUANTITY', 1), ('CREAM', 'MECHANISM', 3)]
#
#
# ADAPALENE 0.3% GEL
# Entities [('ADAPALENE', 'DRUGNAME'), ('0.3%', 'QUANTITY'), ('GEL', 'MECHANISM')]
# Tokens [('ADAPALENE', 'DRUGNAME', 3), ('0.3', 'QUANTITY', 3), ('%', 'QUANTITY', 1), ('GEL', 'MECHANISM', 3)]
#
#
# ADAPALENE 0.3% GEL PUMP
# Entities [('ADAPALENE', 'DRUGNAME'), ('0.3%', 'QUANTITY'), ('GEL PUMP', 'MECHANISM')]
# Tokens [('ADAPALENE', 'DRUGNAME', 3), ('0.3', 'QUANTITY', 3), ('%', 'QUANTITY', 1), ('GEL', 'MECHANISM', 3), ('PUMP', 'MECHANISM', 1)]
#
#
# ADAPALENE-BNZYL PEROX 0.1-2.5%
# Entities [('ADAPALENE-BNZYL PEROX', 'DRUGNAME'), ('0.1-2.5%', 'QUANTITY')]
# Tokens [('ADAPALENE', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('BNZYL', 'DRUGNAME', 1), ('PEROX', 'DRUGNAME', 1), ('0.1', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('2.5', 'QUANTITY', 1), ('%', 'QUANTITY', 1)]
#
#
# ADDERALL 10 MG TABLET
# Entities [('ADDERALL', 'DRUGNAME'), ('10 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ADDERALL', 'DRUGNAME', 3), ('10', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ADDERALL 30 MG TABLET
# Entities [('ADDERALL', 'DRUGNAME'), ('30 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ADDERALL', 'DRUGNAME', 3), ('30', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ADDERALL XR 10 MG CAPSULE
# Entities [('ADDERALL XR', 'DRUGNAME'), ('10 MG', 'QUANTITY'), ('CAPSULE', 'MECHANISM')]
# Tokens [('ADDERALL', 'DRUGNAME', 3), ('XR', 'DRUGNAME', 1), ('10', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPSULE', 'MECHANISM', 3)]
#
#
# ADDERALL XR 15 MG CAPSULE
# Entities [('ADDERALL XR', 'DRUGNAME'), ('15 MG', 'QUANTITY'), ('CAPSULE', 'MECHANISM')]
# Tokens [('ADDERALL', 'DRUGNAME', 3), ('XR', 'DRUGNAME', 1), ('15', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPSULE', 'MECHANISM', 3)]
#
#
# ADDERALL XR 20 MG CAPSULE
# Entities [('ADDERALL XR', 'DRUGNAME'), ('20 MG', 'QUANTITY'), ('CAPSULE', 'MECHANISM')]
# Tokens [('ADDERALL', 'DRUGNAME', 3), ('XR', 'DRUGNAME', 1), ('20', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPSULE', 'MECHANISM', 3)]
#
#
# ADDERALL XR 30 MG CAPSULE
# Entities [('ADDERALL XR', 'DRUGNAME'), ('30 MG', 'QUANTITY'), ('CAPSULE', 'MECHANISM')]
# Tokens [('ADDERALL', 'DRUGNAME', 3), ('XR', 'DRUGNAME', 1), ('30', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPSULE', 'MECHANISM', 3)]
#
#
# ADDERALL XR 5 MG CAPSULE
# Entities [('ADDERALL XR', 'DRUGNAME'), ('5 MG', 'QUANTITY'), ('CAPSULE', 'MECHANISM')]
# Tokens [('ADDERALL', 'DRUGNAME', 3), ('XR', 'DRUGNAME', 1), ('5', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPSULE', 'MECHANISM', 3)]
#
#
# ADHANSIA XR 25 MG CAPSULE
# Entities [('ADHANSIA XR', 'DRUGNAME'), ('25 MG', 'QUANTITY'), ('CAPSULE', 'MECHANISM')]
# Tokens [('ADHANSIA', 'DRUGNAME', 3), ('XR', 'DRUGNAME', 1), ('25', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPSULE', 'MECHANISM', 3)]
#
#
# ADHANSIA XR 45 MG CAPSULE
# Entities [('ADHANSIA XR', 'DRUGNAME'), ('45 MG', 'QUANTITY'), ('CAPSULE', 'MECHANISM')]
# Tokens [('ADHANSIA', 'DRUGNAME', 3), ('XR', 'DRUGNAME', 1), ('45', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPSULE', 'MECHANISM', 3)]
#
#
# ADHANSIA XR 85 MG CAPSULE
# Entities [('ADHANSIA XR', 'DRUGNAME'), ('85 MG', 'QUANTITY'), ('CAPSULE', 'MECHANISM')]
# Tokens [('ADHANSIA', 'DRUGNAME', 3), ('XR', 'DRUGNAME', 1), ('85', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPSULE', 'MECHANISM', 3)]
#
#
# ADIPEX-P 37.5 MG TABLET
# Entities [('ADIPEX-P', 'DRUGNAME'), ('37.5 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ADIPEX', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('P', 'DRUGNAME', 1), ('37.5', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ADMELOG 100 UNIT/ML VIAL
# Entities [('ADMELOG', 'DRUGNAME'), ('100 UNIT/ML', 'QUANTITY'), ('VIAL', 'MECHANISM')]
# Tokens [('ADMELOG', 'DRUGNAME', 3), ('100', 'QUANTITY', 3), ('UNIT', 'QUANTITY', 1), ('/', 'QUANTITY', 1), ('ML', 'QUANTITY', 1), ('VIAL', 'MECHANISM', 3)]
#
#
# ADMELOG SOLOSTAR 100 UNIT/ML
# Entities [('ADMELOG SOLOSTAR', 'DRUGNAME'), ('100 UNIT/ML', 'QUANTITY')]
# Tokens [('ADMELOG', 'DRUGNAME', 3), ('SOLOSTAR', 'DRUGNAME', 1), ('100', 'QUANTITY', 3), ('UNIT', 'QUANTITY', 1), ('/', 'QUANTITY', 1), ('ML', 'QUANTITY', 1)]
#
#
# ADVAIR 100-50 DISKUS
# Entities [('ADVAIR', 'DRUGNAME'), ('100-50', 'QUANTITY'), ('DISKUS', 'MECHANISM')]
# Tokens [('ADVAIR', 'DRUGNAME', 3), ('100', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('50', 'QUANTITY', 1), ('DISKUS', 'MECHANISM', 3)]
#
#
# ADVAIR 250-50 DISKUS
# Entities [('ADVAIR', 'DRUGNAME'), ('250-50', 'QUANTITY'), ('DISKUS', 'MECHANISM')]
# Tokens [('ADVAIR', 'DRUGNAME', 3), ('250', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('50', 'QUANTITY', 1), ('DISKUS', 'MECHANISM', 3)]
#
#
# ADVAIR 500-50 DISKUS
# Entities [('ADVAIR', 'DRUGNAME'), ('500-50', 'QUANTITY'), ('DISKUS', 'MECHANISM')]
# Tokens [('ADVAIR', 'DRUGNAME', 3), ('500', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('50', 'QUANTITY', 1), ('DISKUS', 'MECHANISM', 3)]
#
#
# ADVAIR HFA 115-21 MCG INHALER
# Entities [('ADVAIR HFA', 'DRUGNAME'), ('115-21 MCG', 'QUANTITY'), ('INHALER', 'MECHANISM')]
# Tokens [('ADVAIR', 'DRUGNAME', 3), ('HFA', 'DRUGNAME', 1), ('115', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('21', 'QUANTITY', 1), ('MCG', 'QUANTITY', 1), ('INHALER', 'MECHANISM', 3)]
#
#
# ADVAIR HFA 45-21 MCG INHALER
# Entities [('ADVAIR HFA', 'DRUGNAME'), ('45-21 MCG', 'QUANTITY'), ('INHALER', 'MECHANISM')]
# Tokens [('ADVAIR', 'DRUGNAME', 3), ('HFA', 'DRUGNAME', 1), ('45', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('21', 'QUANTITY', 1), ('MCG', 'QUANTITY', 1), ('INHALER', 'MECHANISM', 3)]
#
#
# ADZENYS XR-ODT 12.5 MG TABLET
# Entities [('ADZENYS XR-ODT', 'DRUGNAME'), ('12.5 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ADZENYS', 'DRUGNAME', 3), ('XR', 'DRUGNAME', 1), ('-', 'DRUGNAME', 1), ('ODT', 'DRUGNAME', 1), ('12.5', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ADZENYS XR-ODT 15.7 MG TABLET
# Entities [('ADZENYS XR-ODT', 'DRUGNAME'), ('15.7 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ADZENYS', 'DRUGNAME', 3), ('XR', 'DRUGNAME', 1), ('-', 'DRUGNAME', 1), ('ODT', 'DRUGNAME', 1), ('15.7', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ADZENYS XR-ODT 18.8 MG TABLET
# Entities [('ADZENYS XR-ODT', 'DRUGNAME'), ('18.8 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ADZENYS', 'DRUGNAME', 3), ('XR', 'DRUGNAME', 1), ('-', 'DRUGNAME', 1), ('ODT', 'DRUGNAME', 1), ('18.8', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ADZENYS XR-ODT 6.3 MG TABLET
# Entities [('ADZENYS XR-ODT', 'DRUGNAME'), ('6.3 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ADZENYS', 'DRUGNAME', 3), ('XR', 'DRUGNAME', 1), ('-', 'DRUGNAME', 1), ('ODT', 'DRUGNAME', 1), ('6.3', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ADZENYS XR-ODT 9.4 MG TABLET
# Entities [('ADZENYS XR-ODT', 'DRUGNAME'), ('9.4 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ADZENYS', 'DRUGNAME', 3), ('XR', 'DRUGNAME', 1), ('-', 'DRUGNAME', 1), ('ODT', 'DRUGNAME', 1), ('9.4', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# AFIRMELLE-28 TABLET
# Entities [('AFIRMELLE-28', 'DRUGNAME'), ('TABLET', 'MECHANISM')]
# Tokens [('AFIRMELLE-28', 'DRUGNAME', 3), ('TABLET', 'MECHANISM', 3)]
#
#
# AFTERA 1.5 MG TABLET
# Entities [('AFTERA', 'DRUGNAME'), ('1.5 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('AFTERA', 'DRUGNAME', 3), ('1.5', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# AIMOVIG 140 MG/ML AUTOINJECTOR
# Entities [('AIMOVIG', 'DRUGNAME'), ('140 MG/ML', 'QUANTITY'), ('AUTOINJECTOR', 'MECHANISM')]
# Tokens [('AIMOVIG', 'DRUGNAME', 3), ('140', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('/', 'QUANTITY', 1), ('ML', 'QUANTITY', 1), ('AUTOINJECTOR', 'MECHANISM', 3)]
#
#
# AIMOVIG 70 MG/ML AUTOINJECTOR
# Entities [('AIMOVIG', 'DRUGNAME'), ('70 MG/ML', 'QUANTITY'), ('AUTOINJECTOR', 'MECHANISM')]
# Tokens [('AIMOVIG', 'DRUGNAME', 3), ('70', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('/', 'QUANTITY', 1), ('ML', 'QUANTITY', 1), ('AUTOINJECTOR', 'MECHANISM', 3)]
#
#
# AJOVY 225 MG/1.5 ML AUTOINJECT
# Entities [('AJOVY', 'DRUGNAME'), ('225 MG/1.5 ML', 'QUANTITY'), ('AUTOINJECT', 'MECHANISM')]
# Tokens [('AJOVY', 'DRUGNAME', 3), ('225', 'QUANTITY', 3), ('MG/1.5', 'QUANTITY', 1), ('ML', 'QUANTITY', 1), ('AUTOINJECT', 'MECHANISM', 3)]
#
#
# AJOVY 225 MG/1.5 ML SYRINGE
# Entities [('AJOVY', 'DRUGNAME'), ('225 MG/1.5 ML', 'QUANTITY'), ('SYRINGE', 'MECHANISM')]
# Tokens [('AJOVY', 'DRUGNAME', 3), ('225', 'QUANTITY', 3), ('MG/1.5', 'QUANTITY', 1), ('ML', 'QUANTITY', 1), ('SYRINGE', 'MECHANISM', 3)]
#
#
# ALA-HIST IR 2 MG TABLET
# Entities [('ALA-HIST IR', 'DRUGNAME'), ('2 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALA', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('HIST', 'DRUGNAME', 1), ('IR', 'DRUGNAME', 1), ('2', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALA-HIST PE 2-10 MG TABLET
# Entities [('ALA-HIST PE', 'DRUGNAME'), ('2-10 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALA', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('HIST', 'DRUGNAME', 1), ('PE', 'DRUGNAME', 1), ('2', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('10', 'QUANTITY', 1), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALAWAY 0.025% EYE DROPS
# Entities [('ALAWAY', 'DRUGNAME'), ('0.025%', 'QUANTITY'), ('EYE DROPS', 'MECHANISM')]
# Tokens [('ALAWAY', 'DRUGNAME', 3), ('0.025', 'QUANTITY', 3), ('%', 'QUANTITY', 1), ('EYE', 'MECHANISM', 3), ('DROPS', 'MECHANISM', 1)]
#
#
# ALBENDAZOLE 200 MG TABLET
# Entities [('ALBENDAZOLE', 'DRUGNAME'), ('200 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALBENDAZOLE', 'DRUGNAME', 3), ('200', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALBUTEROL HFA 90 MCG INHALER
# Entities [('ALBUTEROL HFA', 'DRUGNAME'), ('90 MCG', 'QUANTITY'), ('INHALER', 'MECHANISM')]
# Tokens [('ALBUTEROL', 'DRUGNAME', 3), ('HFA', 'DRUGNAME', 1), ('90', 'QUANTITY', 3), ('MCG', 'QUANTITY', 1), ('INHALER', 'MECHANISM', 3)]
#
#
# ALBUTEROL SUL 0.63 MG/3 ML SOL
# Entities [('ALBUTEROL SUL', 'DRUGNAME'), ('0.63 MG/3 ML', 'QUANTITY'), ('SOL', 'MECHANISM')]
# Tokens [('ALBUTEROL', 'DRUGNAME', 3), ('SUL', 'DRUGNAME', 1), ('0.63', 'QUANTITY', 3), ('MG/3', 'QUANTITY', 1), ('ML', 'QUANTITY', 1), ('SOL', 'MECHANISM', 3)]
#
#
# ALBUTEROL SUL 1.25 MG/3 ML SOL
# Entities [('ALBUTEROL SUL', 'DRUGNAME'), ('1.25 MG/3 ML', 'QUANTITY'), ('SOL', 'MECHANISM')]
# Tokens [('ALBUTEROL', 'DRUGNAME', 3), ('SUL', 'DRUGNAME', 1), ('1.25', 'QUANTITY', 3), ('MG/3', 'QUANTITY', 1), ('ML', 'QUANTITY', 1), ('SOL', 'MECHANISM', 3)]
#
#
# ALBUTEROL SUL 2.5 MG/3 ML SOLN
# Entities [('ALBUTEROL SUL', 'DRUGNAME'), ('2.5 MG/3 ML', 'QUANTITY'), ('SOLN', 'MECHANISM')]
# Tokens [('ALBUTEROL', 'DRUGNAME', 3), ('SUL', 'DRUGNAME', 1), ('2.5', 'QUANTITY', 3), ('MG/3', 'QUANTITY', 1), ('ML', 'QUANTITY', 1), ('SOLN', 'MECHANISM', 3)]
#
#
# ALBUTEROL SULFATE 2 MG TAB
# Entities [('ALBUTEROL SULFATE', 'DRUGNAME'), ('2 MG', 'QUANTITY'), ('TAB', 'MECHANISM')]
# Tokens [('ALBUTEROL', 'DRUGNAME', 3), ('SULFATE', 'DRUGNAME', 1), ('2', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TAB', 'MECHANISM', 3)]
#
#
# ALBUTEROL SULFATE 4 MG TAB
# Entities [('ALBUTEROL SULFATE', 'DRUGNAME'), ('4 MG', 'QUANTITY'), ('TAB', 'MECHANISM')]
# Tokens [('ALBUTEROL', 'DRUGNAME', 3), ('SULFATE', 'DRUGNAME', 1), ('4', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TAB', 'MECHANISM', 3)]
#
#
# ALCLOMETASONE DIPR 0.05% OINT
# Entities [('ALCLOMETASONE DIPR', 'DRUGNAME'), ('0.05%', 'QUANTITY'), ('OINT', 'MECHANISM')]
# Tokens [('ALCLOMETASONE', 'DRUGNAME', 3), ('DIPR', 'DRUGNAME', 1), ('0.05', 'QUANTITY', 3), ('%', 'QUANTITY', 1), ('OINT', 'MECHANISM', 3)]
#
#
# ALCLOMETASONE DIPRO 0.05% CRM
# Entities [('ALCLOMETASONE DIPRO', 'DRUGNAME'), ('0.05%', 'QUANTITY'), ('CRM', 'MECHANISM')]
# Tokens [('ALCLOMETASONE', 'DRUGNAME', 3), ('DIPRO', 'DRUGNAME', 1), ('0.05', 'QUANTITY', 3), ('%', 'QUANTITY', 1), ('CRM', 'MECHANISM', 3)]
#
#
# ALENDRONATE SODIUM 35 MG TAB
# Entities [('ALENDRONATE SODIUM', 'DRUGNAME'), ('35 MG', 'QUANTITY'), ('TAB', 'MECHANISM')]
# Tokens [('ALENDRONATE', 'DRUGNAME', 3), ('SODIUM', 'DRUGNAME', 1), ('35', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TAB', 'MECHANISM', 3)]
#
#
# ALENDRONATE SODIUM 70 MG TAB
# Entities [('ALENDRONATE SODIUM', 'DRUGNAME'), ('70 MG', 'QUANTITY'), ('TAB', 'MECHANISM')]
# Tokens [('ALENDRONATE', 'DRUGNAME', 3), ('SODIUM', 'DRUGNAME', 1), ('70', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TAB', 'MECHANISM', 3)]
#
#
# ALERT AID 200 MG TABLET
# Entities [('ALERT AID', 'DRUGNAME'), ('200 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALERT', 'DRUGNAME', 3), ('AID', 'DRUGNAME', 1), ('200', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALFUZOSIN HCL ER 10 MG TABLET
# Entities [('ALFUZOSIN HCL ER', 'DRUGNAME'), ('10 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALFUZOSIN', 'DRUGNAME', 3), ('HCL', 'DRUGNAME', 1), ('ER', 'DRUGNAME', 1), ('10', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALISKIREN 300 MG TABLET
# Entities [('ALISKIREN', 'DRUGNAME'), ('300 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALISKIREN', 'DRUGNAME', 3), ('300', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALL DAY ALLERGY 10 MG TABLET
# Entities [('ALL DAY ALLERGY', 'DRUGNAME'), ('10 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALL', 'DRUGNAME', 3), ('DAY', 'DRUGNAME', 1), ('ALLERGY', 'DRUGNAME', 1), ('10', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALL DAY ALLERGY-D TABLET
# Entities [('ALL DAY ALLERGY-D', 'DRUGNAME'), ('TABLET', 'MECHANISM')]
# Tokens [('ALL', 'DRUGNAME', 3), ('DAY', 'DRUGNAME', 1), ('ALLERGY', 'DRUGNAME', 1), ('-', 'DRUGNAME', 1), ('D', 'DRUGNAME', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALL DAY PAIN RELIEF 220 MG TAB
# Entities [('ALL DAY PAIN RELIEF', 'DRUGNAME'), ('220 MG', 'QUANTITY'), ('TAB', 'MECHANISM')]
# Tokens [('ALL', 'DRUGNAME', 3), ('DAY', 'DRUGNAME', 1), ('PAIN', 'DRUGNAME', 1), ('RELIEF', 'DRUGNAME', 1), ('220', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TAB', 'MECHANISM', 3)]
#
#
# ALL DAY RELIEF 220 MG CAPLET
# Entities [('ALL DAY RELIEF', 'DRUGNAME'), ('220 MG', 'QUANTITY'), ('CAPLET', 'MECHANISM')]
# Tokens [('ALL', 'DRUGNAME', 3), ('DAY', 'DRUGNAME', 1), ('RELIEF', 'DRUGNAME', 1), ('220', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPLET', 'MECHANISM', 3)]
#
#
# ALL DAY RELIEF 220 MG TABLET
# Entities [('ALL DAY RELIEF', 'DRUGNAME'), ('220 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALL', 'DRUGNAME', 3), ('DAY', 'DRUGNAME', 1), ('RELIEF', 'DRUGNAME', 1), ('220', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALLER-CHLOR 4 MG TABLET
# Entities [('ALLER-CHLOR', 'DRUGNAME'), ('4 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALLER', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('CHLOR', 'DRUGNAME', 1), ('4', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALLER-EASE 60 MG TABLET
# Entities [('ALLER-EASE', 'DRUGNAME'), ('60 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALLER', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('EASE', 'DRUGNAME', 1), ('60', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALLERGY 25 MG CAPSULE
# Entities [('ALLERGY', 'DRUGNAME'), ('25 MG', 'QUANTITY'), ('CAPSULE', 'MECHANISM')]
# Tokens [('ALLERGY', 'DRUGNAME', 3), ('25', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPSULE', 'MECHANISM', 3)]
#
#
# ALLERGY 25 MG TABLET
# Entities [('ALLERGY', 'DRUGNAME'), ('25 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALLERGY', 'DRUGNAME', 3), ('25', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALLERGY 4 MG TABLET
# Entities [('ALLERGY', 'DRUGNAME'), ('4 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALLERGY', 'DRUGNAME', 3), ('4', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALLERGY 50 MG/20 ML SOLUTION
# Entities [('ALLERGY', 'DRUGNAME'), ('50 MG/20 ML', 'QUANTITY'), ('SOLUTION', 'MECHANISM')]
# Tokens [('ALLERGY', 'DRUGNAME', 3), ('50', 'QUANTITY', 3), ('MG/20', 'QUANTITY', 1), ('ML', 'QUANTITY', 1), ('SOLUTION', 'MECHANISM', 3)]
#
#
# ALLERGY-CONGEST 12HR 60-120 MG
# Entities [('ALLERGY-CONGEST 12HR', 'DRUGNAME'), ('60-120 MG', 'QUANTITY')]
# Tokens [('ALLERGY', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('CONGEST', 'DRUGNAME', 1), ('12HR', 'DRUGNAME', 1), ('60', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('120', 'QUANTITY', 1), ('MG', 'QUANTITY', 1)]
#
#
# ALLERGY-CONGESTION RLF 12H TAB
# Entities [('ALLERGY-CONGESTION RLF', 'DRUGNAME'), ('12H', 'QUANTITY'), ('TAB', 'MECHANISM')]
# Tokens [('ALLERGY', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('CONGESTION', 'DRUGNAME', 1), ('RLF', 'DRUGNAME', 1), ('12H', 'QUANTITY', 3), ('TAB', 'MECHANISM', 3)]
#
#
# ALLERGY (LORATADINE) 10 MG TAB
# Entities [('ALLERGY (LORATADINE)', 'DRUGNAME'), ('10 MG', 'QUANTITY'), ('TAB', 'MECHANISM')]
# Tokens [('ALLERGY', 'DRUGNAME', 3), ('(', 'DRUGNAME', 1), ('LORATADINE', 'DRUGNAME', 1), (')', 'DRUGNAME', 1), ('10', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TAB', 'MECHANISM', 3)]
#
#
# ALLERGY MULTI-SYMPTOM CAPLET
# Entities [('ALLERGY MULTI-SYMPTOM', 'DRUGNAME'), ('CAPLET', 'MECHANISM')]
# Tokens [('ALLERGY', 'DRUGNAME', 3), ('MULTI', 'DRUGNAME', 1), ('-', 'DRUGNAME', 1), ('SYMPTOM', 'DRUGNAME', 1), ('CAPLET', 'MECHANISM', 3)]
#
#
# ALLERGY RELIEF 180 MG TABLET
# Entities [('ALLERGY RELIEF', 'DRUGNAME'), ('180 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALLERGY', 'DRUGNAME', 3), ('RELIEF', 'DRUGNAME', 1), ('180', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALLERGY RELIEF 25 MG CAPSULE
# Entities [('ALLERGY RELIEF', 'DRUGNAME'), ('25 MG', 'QUANTITY'), ('CAPSULE', 'MECHANISM')]
# Tokens [('ALLERGY', 'DRUGNAME', 3), ('RELIEF', 'DRUGNAME', 1), ('25', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPSULE', 'MECHANISM', 3)]
#
#
# ALLERGY RELIEF 25 MG SOFTGEL
# Entities [('ALLERGY RELIEF', 'DRUGNAME'), ('25 MG', 'QUANTITY'), ('SOFTGEL', 'MECHANISM')]
# Tokens [('ALLERGY', 'DRUGNAME', 3), ('RELIEF', 'DRUGNAME', 1), ('25', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('SOFTGEL', 'MECHANISM', 3)]
#
#
# ALLERGY RELIEF 25 MG TABLET
# Entities [('ALLERGY RELIEF', 'DRUGNAME'), ('25 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALLERGY', 'DRUGNAME', 3), ('RELIEF', 'DRUGNAME', 1), ('25', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALLERGY RELIEF 50 MCG SPRAY
# Entities [('ALLERGY RELIEF', 'DRUGNAME'), ('50 MCG', 'QUANTITY'), ('SPRAY', 'MECHANISM')]
# Tokens [('ALLERGY', 'DRUGNAME', 3), ('RELIEF', 'DRUGNAME', 1), ('50', 'QUANTITY', 3), ('MCG', 'QUANTITY', 1), ('SPRAY', 'MECHANISM', 3)]
#
#
# ALLERGY RELIEF 5 MG/5 ML SOLN
# Entities [('ALLERGY RELIEF', 'DRUGNAME'), ('5 MG/5 ML', 'QUANTITY'), ('SOLN', 'MECHANISM')]
# Tokens [('ALLERGY', 'DRUGNAME', 3), ('RELIEF', 'DRUGNAME', 1), ('5', 'QUANTITY', 3), ('MG/5', 'QUANTITY', 1), ('ML', 'QUANTITY', 1), ('SOLN', 'MECHANISM', 3)]
#
#
# ALLERGY RELIEF D-12 TABLET
# Entities [('ALLERGY RELIEF D-12', 'DRUGNAME'), ('TABLET', 'MECHANISM')]
# Tokens [('ALLERGY', 'DRUGNAME', 3), ('RELIEF', 'DRUGNAME', 1), ('D-12', 'DRUGNAME', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALLERGY RELIEF D-24HR TABLET
# Entities [('ALLERGY RELIEF D-24HR', 'DRUGNAME'), ('TABLET', 'MECHANISM')]
# Tokens [('ALLERGY', 'DRUGNAME', 3), ('RELIEF', 'DRUGNAME', 1), ('D-24HR', 'DRUGNAME', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALLERGY RELIEF-NASAL DECONG TB
# Entities [('ALLERGY RELIEF-NASAL DECONG', 'DRUGNAME'), ('TB', 'MECHANISM')]
# Tokens [('ALLERGY', 'DRUGNAME', 3), ('RELIEF', 'DRUGNAME', 1), ('-', 'DRUGNAME', 1), ('NASAL', 'DRUGNAME', 1), ('DECONG', 'DRUGNAME', 1), ('TB', 'MECHANISM', 3)]
#
#
# ALLERGY RLF (CETRZN) 10 MG TAB
# Entities [('ALLERGY RLF (CETRZN)', 'DRUGNAME'), ('10 MG', 'QUANTITY'), ('TAB', 'MECHANISM')]
# Tokens [('ALLERGY', 'DRUGNAME', 3), ('RLF', 'DRUGNAME', 1), ('(', 'DRUGNAME', 1), ('CETRZN', 'DRUGNAME', 1), (')', 'DRUGNAME', 1), ('10', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TAB', 'MECHANISM', 3)]
#
#
# ALLERGY-TIME 4 MG TABLET
# Entities [('ALLERGY-TIME', 'DRUGNAME'), ('4 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALLERGY', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('TIME', 'DRUGNAME', 1), ('4', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALL-NITE COLD-FLU RELIEF LIQ
# Entities [('ALL-NITE COLD-FLU RELIEF', 'DRUGNAME'), ('LIQ', 'MECHANISM')]
# Tokens [('ALL', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('NITE', 'DRUGNAME', 1), ('COLD', 'DRUGNAME', 1), ('-', 'DRUGNAME', 1), ('FLU', 'DRUGNAME', 1), ('RELIEF', 'DRUGNAME', 1), ('LIQ', 'MECHANISM', 3)]
#
#
# ALLOPURINOL 300 MG TABLET
# Entities [('ALLOPURINOL', 'DRUGNAME'), ('300 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALLOPURINOL', 'DRUGNAME', 3), ('300', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALMACONE-2 LIQUID
# Entities [('ALMACONE-2', 'DRUGNAME'), ('LIQUID', 'MECHANISM')]
# Tokens [('ALMACONE-2', 'DRUGNAME', 3), ('LIQUID', 'MECHANISM', 3)]
#
#
# ALMACONE SUSPENSION
# Entities [('ALMACONE', 'DRUGNAME'), ('SUSPENSION', 'MECHANISM')]
# Tokens [('ALMACONE', 'DRUGNAME', 3), ('SUSPENSION', 'MECHANISM', 3)]
#
#
# ALMOTRIPTAN MALATE 12.5 MG TAB
# Entities [('ALMOTRIPTAN MALATE', 'DRUGNAME'), ('12.5 MG', 'QUANTITY'), ('TAB', 'MECHANISM')]
# Tokens [('ALMOTRIPTAN', 'DRUGNAME', 3), ('MALATE', 'DRUGNAME', 1), ('12.5', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TAB', 'MECHANISM', 3)]
#
#
# ALOGLIPTIN 25 MG TABLET
# Entities [('ALOGLIPTIN', 'DRUGNAME'), ('25 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALOGLIPTIN', 'DRUGNAME', 3), ('25', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALOGLIPTIN 6.25 MG TABLET
# Entities [('ALOGLIPTIN', 'DRUGNAME'), ('6.25 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALOGLIPTIN', 'DRUGNAME', 3), ('6.25', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALOGLIPTIN-METFORMIN 12.5-1000
# Entities [('ALOGLIPTIN-METFORMIN', 'DRUGNAME'), ('12.5-1000', 'QUANTITY')]
# Tokens [('ALOGLIPTIN', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('METFORMIN', 'DRUGNAME', 1), ('12.5', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('1000', 'QUANTITY', 1)]
#
#
# ALOGLIPTIN-METFORMIN 12.5-500
# Entities [('ALOGLIPTIN-METFORMIN', 'DRUGNAME'), ('12.5-500', 'QUANTITY')]
# Tokens [('ALOGLIPTIN', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('METFORMIN', 'DRUGNAME', 1), ('12.5', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('500', 'QUANTITY', 1)]
#
#
# ALOSETRON HCL 1 MG TABLET
# Entities [('ALOSETRON HCL', 'DRUGNAME'), ('1 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALOSETRON', 'DRUGNAME', 3), ('HCL', 'DRUGNAME', 1), ('1', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALPHAGAN P 0.15% EYE DROPS
# Entities [('ALPHAGAN P', 'DRUGNAME'), ('0.15%', 'QUANTITY'), ('EYE DROPS', 'MECHANISM')]
# Tokens [('ALPHAGAN', 'DRUGNAME', 3), ('P', 'DRUGNAME', 1), ('0.15', 'QUANTITY', 3), ('%', 'QUANTITY', 1), ('EYE', 'MECHANISM', 3), ('DROPS', 'MECHANISM', 1)]
#
#
# ALPHAGAN P 0.1% DROPS
# Entities [('ALPHAGAN P', 'DRUGNAME'), ('0.1%', 'QUANTITY'), ('DROPS', 'MECHANISM')]
# Tokens [('ALPHAGAN', 'DRUGNAME', 3), ('P', 'DRUGNAME', 1), ('0.1', 'QUANTITY', 3), ('%', 'QUANTITY', 1), ('DROPS', 'MECHANISM', 3)]
#
#
# ALPRAZOLAM 0.25 MG TABLET
# Entities [('ALPRAZOLAM', 'DRUGNAME'), ('0.25 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALPRAZOLAM', 'DRUGNAME', 3), ('0.25', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALPRAZOLAM 1 MG TABLET
# Entities [('ALPRAZOLAM', 'DRUGNAME'), ('1 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALPRAZOLAM', 'DRUGNAME', 3), ('1', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALPRAZOLAM 2 MG TABLET
# Entities [('ALPRAZOLAM', 'DRUGNAME'), ('2 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALPRAZOLAM', 'DRUGNAME', 3), ('2', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALPRAZOLAM ER 0.5 MG TABLET
# Entities [('ALPRAZOLAM ER', 'DRUGNAME'), ('0.5 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALPRAZOLAM', 'DRUGNAME', 3), ('ER', 'DRUGNAME', 1), ('0.5', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALPRAZOLAM ER 1 MG TABLET
# Entities [('ALPRAZOLAM ER', 'DRUGNAME'), ('1 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALPRAZOLAM', 'DRUGNAME', 3), ('ER', 'DRUGNAME', 1), ('1', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALPRAZOLAM ER 3 MG TABLET
# Entities [('ALPRAZOLAM ER', 'DRUGNAME'), ('3 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALPRAZOLAM', 'DRUGNAME', 3), ('ER', 'DRUGNAME', 1), ('3', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALPRAZOLAM XR 3 MG TABLET
# Entities [('ALPRAZOLAM XR', 'DRUGNAME'), ('3 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALPRAZOLAM', 'DRUGNAME', 3), ('XR', 'DRUGNAME', 1), ('3', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALREX 0.2% EYE DROPS
# Entities [('ALREX', 'DRUGNAME'), ('0.2%', 'QUANTITY'), ('EYE DROPS', 'MECHANISM')]
# Tokens [('ALREX', 'DRUGNAME', 3), ('0.2', 'QUANTITY', 3), ('%', 'QUANTITY', 1), ('EYE', 'MECHANISM', 3), ('DROPS', 'MECHANISM', 1)]
#
#
# ALTACE 10 MG CAPSULE
# Entities [('ALTACE', 'DRUGNAME'), ('10 MG', 'QUANTITY'), ('CAPSULE', 'MECHANISM')]
# Tokens [('ALTACE', 'DRUGNAME', 3), ('10', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPSULE', 'MECHANISM', 3)]
#
#
# ALTAVERA-28 TABLET
# Entities [('ALTAVERA-28', 'DRUGNAME'), ('TABLET', 'MECHANISM')]
# Tokens [('ALTAVERA-28', 'DRUGNAME', 3), ('TABLET', 'MECHANISM', 3)]
#
#
# ALUMINUM HYDROXIDE GEL
# Entities [('ALUMINUM HYDROXIDE GEL', 'DRUGNAME')]
# Tokens [('ALUMINUM', 'DRUGNAME', 3), ('HYDROXIDE', 'DRUGNAME', 1), ('GEL', 'DRUGNAME', 1)]
#
#
# ALVESCO 160 MCG INHALER
# Entities [('ALVESCO', 'DRUGNAME'), ('160 MCG', 'QUANTITY'), ('INHALER', 'MECHANISM')]
# Tokens [('ALVESCO', 'DRUGNAME', 3), ('160', 'QUANTITY', 3), ('MCG', 'QUANTITY', 1), ('INHALER', 'MECHANISM', 3)]
#
#
# ALVESCO 80 MCG INHALER
# Entities [('ALVESCO', 'DRUGNAME'), ('80 MCG', 'QUANTITY'), ('INHALER', 'MECHANISM')]
# Tokens [('ALVESCO', 'DRUGNAME', 3), ('80', 'QUANTITY', 3), ('MCG', 'QUANTITY', 1), ('INHALER', 'MECHANISM', 3)]
#
#
# ALYACEN 1-35 28 TABLET
# Entities [('ALYACEN', 'DRUGNAME'), ('1-35 28', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALYACEN', 'DRUGNAME', 3), ('1', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('35', 'QUANTITY', 1), ('28', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# ALYQ 20 MG TABLET
# Entities [('ALYQ', 'DRUGNAME'), ('20 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('ALYQ', 'DRUGNAME', 3), ('20', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# AMABELZ 0.5 MG-0.1 MG TABLET
# Entities [('AMABELZ', 'DRUGNAME'), ('0.5 MG-0.1 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('AMABELZ', 'DRUGNAME', 3), ('0.5', 'QUANTITY', 3), ('MG-0.1', 'QUANTITY', 1), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# AMABELZ 1 MG-0.5 MG TABLET
# Entities [('AMABELZ', 'DRUGNAME'), ('1 MG-0.5 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('AMABELZ', 'DRUGNAME', 3), ('1', 'QUANTITY', 3), ('MG-0.5', 'QUANTITY', 1), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# AMANTADINE 100 MG CAPSULE
# Entities [('AMANTADINE', 'DRUGNAME'), ('100 MG', 'QUANTITY'), ('CAPSULE', 'MECHANISM')]
# Tokens [('AMANTADINE', 'DRUGNAME', 3), ('100', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPSULE', 'MECHANISM', 3)]
#
#
# AMANTADINE 50 MG/5 ML SOLUTION
# Entities [('AMANTADINE', 'DRUGNAME'), ('50 MG/5 ML', 'QUANTITY'), ('SOLUTION', 'MECHANISM')]
# Tokens [('AMANTADINE', 'DRUGNAME', 3), ('50', 'QUANTITY', 3), ('MG/5', 'QUANTITY', 1), ('ML', 'QUANTITY', 1), ('SOLUTION', 'MECHANISM', 3)]
#
#
# AMBIEN 10 MG TABLET
# Entities [('AMBIEN', 'DRUGNAME'), ('10 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('AMBIEN', 'DRUGNAME', 3), ('10', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# AMBIEN 5 MG TABLET
# Entities [('AMBIEN', 'DRUGNAME'), ('5 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('AMBIEN', 'DRUGNAME', 3), ('5', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# AMETHIA LO TABLET
# Entities [('AMETHIA LO', 'DRUGNAME'), ('TABLET', 'MECHANISM')]
# Tokens [('AMETHIA', 'DRUGNAME', 3), ('LO', 'DRUGNAME', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# AMETHYST 90-20 MCG TABLET
# Entities [('AMETHYST', 'DRUGNAME'), ('90-20 MCG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('AMETHYST', 'DRUGNAME', 3), ('90', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('20', 'QUANTITY', 1), ('MCG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# AMILORIDE HCL 5 MG TABLET
# Entities [('AMILORIDE HCL', 'DRUGNAME'), ('5 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('AMILORIDE', 'DRUGNAME', 3), ('HCL', 'DRUGNAME', 1), ('5', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# AMILORIDE HCL-HYDROCHLOROTHIAZIDE 5-50 MG TAB
# Entities [('AMILORIDE HCL-HYDROCHLOROTHIAZIDE', 'DRUGNAME'), ('5-50 MG', 'QUANTITY'), ('TAB', 'MECHANISM')]
# Tokens [('AMILORIDE', 'DRUGNAME', 3), ('HCL', 'DRUGNAME', 1), ('-', 'DRUGNAME', 1), ('HYDROCHLOROTHIAZIDE', 'DRUGNAME', 1), ('5', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('50', 'QUANTITY', 1), ('MG', 'QUANTITY', 1), ('TAB', 'MECHANISM', 3)]
#
#
# AMIODARONE HCL 200 MG TABLET
# Entities [('AMIODARONE HCL', 'DRUGNAME'), ('200 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('AMIODARONE', 'DRUGNAME', 3), ('HCL', 'DRUGNAME', 1), ('200', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# AMIODARONE HCL 400 MG TABLET
# Entities [('AMIODARONE HCL', 'DRUGNAME'), ('400 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('AMIODARONE', 'DRUGNAME', 3), ('HCL', 'DRUGNAME', 1), ('400', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]
#
#
# AMITIZA 24 MCG CAPSULES
# Entities [('AMITIZA', 'DRUGNAME'), ('24 MCG', 'QUANTITY'), ('CAPSULES', 'MECHANISM')]
# Tokens [('AMITIZA', 'DRUGNAME', 3), ('24', 'QUANTITY', 3), ('MCG', 'QUANTITY', 1), ('CAPSULES', 'MECHANISM', 3)]
#
#
# AMITIZA 8 MCG CAPSULE
# Entities [('AMITIZA', 'DRUGNAME'), ('8 MCG', 'QUANTITY'), ('CAPSULE', 'MECHANISM')]
# Tokens [('AMITIZA', 'DRUGNAME', 3), ('8', 'QUANTITY', 3), ('MCG', 'QUANTITY', 1), ('CAPSULE', 'MECHANISM', 3)]
#
#
# AMLODIPINE-OLMESARTAN 10-40 MG
# Entities [('AMLODIPINE-OLMESARTAN', 'DRUGNAME'), ('10-40 MG', 'QUANTITY')]
# Tokens [('AMLODIPINE', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('OLMESARTAN', 'DRUGNAME', 1), ('10', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('40', 'QUANTITY', 1), ('MG', 'QUANTITY', 1)]
#
#
# AMLODIPINE-OLMESARTAN 5-20 MG
# Entities [('AMLODIPINE-OLMESARTAN', 'DRUGNAME'), ('5-20 MG', 'QUANTITY')]
# Tokens [('AMLODIPINE', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('OLMESARTAN', 'DRUGNAME', 1), ('5', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('20', 'QUANTITY', 1), ('MG', 'QUANTITY', 1)]
#
#
# AMLODIPINE-VALSARTAN 10-160 MG
# Entities [('AMLODIPINE-VALSARTAN', 'DRUGNAME'), ('10-160 MG', 'QUANTITY')]
# Tokens [('AMLODIPINE', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('VALSARTAN', 'DRUGNAME', 1), ('10', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('160', 'QUANTITY', 1), ('MG', 'QUANTITY', 1)]
#
#
# AMLODIPINE-VALSARTAN 10-320 MG
# Entities [('AMLODIPINE-VALSARTAN', 'DRUGNAME'), ('10-320 MG', 'QUANTITY')]
# Tokens [('AMLODIPINE', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('VALSARTAN', 'DRUGNAME', 1), ('10', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('320', 'QUANTITY', 1), ('MG', 'QUANTITY', 1)]
#
#
# AMLODIPINE-VALSARTAN 5-160 MG
# Entities [('AMLODIPINE-VALSARTAN', 'DRUGNAME'), ('5-160 MG', 'QUANTITY')]
# Tokens [('AMLODIPINE', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('VALSARTAN', 'DRUGNAME', 1), ('5', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('160', 'QUANTITY', 1), ('MG', 'QUANTITY', 1)]
#
#
# AMLODIPINE-VALSARTAN 5-320 MG
# Entities [('AMLODIPINE-VALSARTAN', 'DRUGNAME'), ('5-320 MG', 'QUANTITY')]
# Tokens [('AMLODIPINE', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('VALSARTAN', 'DRUGNAME', 1), ('5', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('320', 'QUANTITY', 1), ('MG', 'QUANTITY', 1)]
#
#
# AMLODIPINE-VALSARTAN-HYDROCHLOROTHIAZIDE 10-160-25 MG TAB
# Entities [('AMLODIPINE-VALSARTAN-HYDROCHLOROTHIAZIDE', 'DRUGNAME'), ('10-160-25 MG', 'QUANTITY'), ('TAB', 'MECHANISM')]
# Tokens [('AMLODIPINE', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('VALSARTAN', 'DRUGNAME', 1), ('-', 'DRUGNAME', 1), ('HYDROCHLOROTHIAZIDE', 'DRUGNAME', 1), ('10', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('160', 'QUANTITY', 1), ('-', 'QUANTITY', 1), ('25', 'QUANTITY', 1), ('MG', 'QUANTITY', 1), ('TAB', 'MECHANISM', 3)]
#
#
# AMLODIPINE-VALSARTAN-HYDROCHLOROTHIAZIDE 10-320-25 MG TAB
# Entities [('AMLODIPINE-VALSARTAN-HYDROCHLOROTHIAZIDE', 'DRUGNAME'), ('10-320-25 MG', 'QUANTITY'), ('TAB', 'MECHANISM')]
# Tokens [('AMLODIPINE', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('VALSARTAN', 'DRUGNAME', 1), ('-', 'DRUGNAME', 1), ('HYDROCHLOROTHIAZIDE', 'DRUGNAME', 1), ('10', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('320', 'QUANTITY', 1), ('-', 'QUANTITY', 1), ('25', 'QUANTITY', 1), ('MG', 'QUANTITY', 1), ('TAB', 'MECHANISM', 3)]
#
#
# AMLODIPINE-VALSARTAN-HYDROCHLOROTHIAZIDE 5-160-12.5 MG TAB
# Entities [('AMLODIPINE-VALSARTAN-HYDROCHLOROTHIAZIDE', 'DRUGNAME'), ('5-160-12.5 MG', 'QUANTITY'), ('TAB', 'MECHANISM')]
# Tokens [('AMLODIPINE', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('VALSARTAN', 'DRUGNAME', 1), ('-', 'DRUGNAME', 1), ('HYDROCHLOROTHIAZIDE', 'DRUGNAME', 1), ('5', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('160', 'QUANTITY', 1), ('-', 'QUANTITY', 1), ('12.5', 'QUANTITY', 1), ('MG', 'QUANTITY', 1), ('TAB', 'MECHANISM', 3)]
#
#
# AMLODIPINE-VALSARTAN-HYDROCHLOROTHIAZIDE 5-160-25 MG TAB
# Entities [('AMLODIPINE-VALSARTAN-HYDROCHLOROTHIAZIDE', 'DRUGNAME'), ('5-160-25 MG', 'QUANTITY'), ('TAB', 'MECHANISM')]
# Tokens [('AMLODIPINE', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('VALSARTAN', 'DRUGNAME', 1), ('-', 'DRUGNAME', 1), ('HYDROCHLOROTHIAZIDE', 'DRUGNAME', 1), ('5', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('160', 'QUANTITY', 1), ('-', 'QUANTITY', 1), ('25', 'QUANTITY', 1), ('MG', 'QUANTITY', 1), ('TAB', 'MECHANISM', 3)]
#
#
# AMMONIUM LACTATE 12% CREAM
# Entities [('AMMONIUM LACTATE', 'DRUGNAME'), ('12%', 'QUANTITY'), ('CREAM', 'MECHANISM')]
# Tokens [('AMMONIUM', 'DRUGNAME', 3), ('LACTATE', 'DRUGNAME', 1), ('12', 'QUANTITY', 3), ('%', 'QUANTITY', 1), ('CREAM', 'MECHANISM', 3)]
#
#
# AMMONIUM LACTATE 12% LOTION
# Entities [('AMMONIUM LACTATE', 'DRUGNAME'), ('12%', 'QUANTITY'), ('LOTION', 'MECHANISM')]
# Tokens [('AMMONIUM', 'DRUGNAME', 3), ('LACTATE', 'DRUGNAME', 1), ('12', 'QUANTITY', 3), ('%', 'QUANTITY', 1), ('LOTION', 'MECHANISM', 3)]
#
#
# AMNESTEEM 10 MG CAPSULE
# Entities [('AMNESTEEM', 'DRUGNAME'), ('10 MG', 'QUANTITY'), ('CAPSULE', 'MECHANISM')]
# Tokens [('AMNESTEEM', 'DRUGNAME', 3), ('10', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPSULE', 'MECHANISM', 3)]
#
#
# AMOX-CLAV ER 1,000-62.5 MG TAB
# Entities [('AMOX-CLAV ER', 'DRUGNAME'), ('1,000-62.5 MG', 'QUANTITY'), ('TAB', 'MECHANISM')]
# Tokens [('AMOX', 'DRUGNAME', 3), ('-', 'DRUGNAME', 1), ('CLAV', 'DRUGNAME', 1), ('ER', 'DRUGNAME', 1), ('1,000', 'QUANTITY', 3), ('-', 'QUANTITY', 1), ('62.5', 'QUANTITY', 1), ('MG', 'QUANTITY', 1), ('TAB', 'MECHANISM', 3)]
#
#
# AMOXICILLIN 200 MG/5 ML SUSP
# Entities [('AMOXICILLIN', 'DRUGNAME'), ('200 MG/5 ML', 'QUANTITY'), ('SUSP', 'MECHANISM')]
# Tokens [('AMOXICILLIN', 'DRUGNAME', 3), ('200', 'QUANTITY', 3), ('MG/5', 'QUANTITY', 1), ('ML', 'QUANTITY', 1), ('SUSP', 'MECHANISM', 3)]
#
#
# AMOXICILLIN 250 MG/5 ML SUSP
# Entities [('AMOXICILLIN', 'DRUGNAME'), ('250 MG/5 ML', 'QUANTITY'), ('SUSP', 'MECHANISM')]
# Tokens [('AMOXICILLIN', 'DRUGNAME', 3), ('250', 'QUANTITY', 3), ('MG/5', 'QUANTITY', 1), ('ML', 'QUANTITY', 1), ('SUSP', 'MECHANISM', 3)]
#
#
# AMOXICILLIN 250 MG CAPSULE
# Entities [('AMOXICILLIN', 'DRUGNAME'), ('250 MG', 'QUANTITY'), ('CAPSULE', 'MECHANISM')]
# Tokens [('AMOXICILLIN', 'DRUGNAME', 3), ('250', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPSULE', 'MECHANISM', 3)]
#
#
# AMOXICILLIN 250 MG TAB CHEW
# Entities [('AMOXICILLIN', 'DRUGNAME'), ('250 MG', 'QUANTITY'), ('TAB CHEW', 'MECHANISM')]
# Tokens [('AMOXICILLIN', 'DRUGNAME', 3), ('250', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TAB', 'MECHANISM', 3), ('CHEW', 'MECHANISM', 1)]
#
#
# AMOXICILLIN 500 MG CAPSULE
# Entities [('AMOXICILLIN', 'DRUGNAME'), ('500 MG', 'QUANTITY'), ('CAPSULE', 'MECHANISM')]
# Tokens [('AMOXICILLIN', 'DRUGNAME', 3), ('500', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('CAPSULE', 'MECHANISM', 3)]
#
#
# AMOXICILLIN 500 MG TABLET
# Entities [('AMOXICILLIN', 'DRUGNAME'), ('500 MG', 'QUANTITY'), ('TABLET', 'MECHANISM')]
# Tokens [('AMOXICILLIN', 'DRUGNAME', 3), ('500', 'QUANTITY', 3), ('MG', 'QUANTITY', 1), ('TABLET', 'MECHANISM', 3)]

# %% [markdown]
# ### Saving the model to disk

# %%
nlp.to_disk('C:/Users/Lofgran/Documents/Python Scripts/TDI/DrugPricePredictor/models/drug_names')
